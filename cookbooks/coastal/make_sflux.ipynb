# %%
from herbie import Herbie
from herbie.toolbox import EasyMap, pc
from herbie import paint

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import xarray as xr

# %%
"""Get HRRR data using Herbie instead of wgrib2"""
H = Herbie('2024-02-19', model='hrrr', product='sfc', fxx=0)

variables = [
    'UGRD:10 m above ground',
    'VGRD:10 m above ground', 
    'TMP:2 m above ground',
    'SPFH:2 m above ground',
    'APCP:surface',
    'DSWRF:surface',
    'DLWRF:surface',
    
]

ds = H.xarray('PRES:surface')
ds
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2024-Feb-19 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# 👨🏻‍🏭 Created directory: [/Users/taddbindas/data/hrrr/20240219]
# <xarray.Dataset> Size: 38MB
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 8B 2024-02-19
#     step                 timedelta64[ns] 8B 00:00:00
#     surface              float64 8B 0.0
#     latitude             (y, x) float64 15MB 21.14 21.15 21.15 ... 47.85 47.84
#     longitude            (y, x) float64 15MB 237.3 237.3 237.3 ... 299.0 299.1
#     valid_time           datetime64[ns] 8B 2024-02-19
#     gribfile_projection  object 8B None
# Dimensions without coordinates: y, x
# Data variables:
#     sp                   (y, x) float32 8MB 1.018e+05 1.018e+05 ... 1.003e+05
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
#     description:             High-Resolution Rapid Refresh - CONUS
#     remote_grib:             https://noaa-hrrr-bdp-pds.s3.amazonaws.com/hrrr....
#     local_grib:              /Users/taddbindas/data/hrrr/20240219/subset_77ef...
#     search:                  PRES:surface
